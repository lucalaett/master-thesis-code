# %%
##########################################################################################################
#Fit for m, theta, chi_i .....
#all the other data is given... 
##########################################################################################################

# %%
import os
os.chdir(os.path.dirname(os.getcwd()))

import numpy as np
import data.epta_data as dt

from src.residual_fct import timing_residual

# %%
#measurement data: pulsar Jnames, emission periods, measurmenet timespans, rms timing residual (whitened)
p_name = dt.p_name()
p_T = dt.p_period() #GeV^-1
p_tend = dt.p_tend() #GeV^-1
p_wrms = dt.p_wrms() #GeV^-1
# Out:
# ['J0030+0451' 'J0613−0200' 'J0751+1807' 'J0900−3144' 'J1012+5307'
#  'J1022+1001' 'J1024−0719' 'J1455−3330' 'J1600−3053' 'J1640+2224'
#  'J1713+0747' 'J1730−2304' 'J1738+0333' 'J1744−1134' 'J1751−2857'
#  'J1801−1417' 'J1804−2717' 'J1843−1113' 'J1857+0943' 'J1909−3744'
#  'J1910+1256' 'J1911+1347' 'J1918−0642' 'J2124−3358' 'J2322+2057']

# %%
#given parameters 
G = 6.7e-39 #GeV^-2
rho = 2.3e-42  #GeV^4
delta = 0.1
H = 1.5e-42 #GeV 
a = 1.0
deltadot = H*delta /(2*np.sqrt(np.pi))
k =  100/1.56e38 #GeV

# %%
#priors for m, theta, chi_i

# %%
#timing_residual(G, chi, T, rho, delta, H, a, deltadot, m , theta, k, tend)
#not yet: chi, m, theta
